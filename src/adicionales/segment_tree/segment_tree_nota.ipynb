# %%
# %run segment_tree_consulta.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="840">
# ...

# %%
# %run segment_tree.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="840">
# ...
