# %%
# %run bellman_ford_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="1140">
# {0: [3, 5, 1], 3: [0, 7, 6, 4], 5: [0, 2, 13, 9], 1: [0], 2: [5, 8], 8: [2, 12], 7: [3], 6: [3, 10], 4: [3, 11], 11: [4], 13: [5], 9: [5], 10: [6, 14], 12: [8], 14: [10]}
# el inicial es 12
