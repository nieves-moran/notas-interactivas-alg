# %%
# %run bellman_ford_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="640">
# {0: [5, 4, 1], 5: [0, 6], 4: [0, 3, 14], 1: [0, 8, 2], 8: [1], 2: [1, 7], 7: [2, 11], 3: [10, 9, 4], 10: [3, 13, 12], 9: [3, 15], 14: [4], 6: [5], 11: [7, 17], 15: [9], 13: [10], 12: [10, 16], 17: [11], 16: [12]}
# el inicial es 3
