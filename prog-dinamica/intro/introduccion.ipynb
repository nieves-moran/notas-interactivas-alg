# %% [markdown]
# Ahora los intervalos tienen un peso
# Diseño de un algoritmo recursivo
# no hay una regla greedy conocida
# comenzamos con un algoritmo recursivo
# luego a una forma iterativa
# luego definimos el problema
# ahora los intervalos tienen un valor o peso
# son compatibles si no se overlap
# maximizar la suma de los valores escogidos
# supognamos que estar ordenados por finalizacion
# definimos pj como ...
# Supogamos que tenemos a O
# el intervalo n pertenece o no
# exploramos ambos casos
# si esta entonces O debe incluir una solucion optima para
# with no danger of overlapping requests
# el problema pero con el intervalo de 1 a j
# problemas mas pequeños y sea OPT el valor de esta solucion
# como son los dos posibles, entonces podemos decir que optj es el maximo
# cuando pertenece a la solucion optima
# ecuacion de recurrencia, nos da un algoritmo recursivo para calcular opt n
# escribe e lalgoritmo,
# como sabes que es cierto
# tomara tiempo exponencial
# el numero de llamadas crecera mucho
# Memoizing the recursion
# cuantos problemas dierentes
# redundancia
# memoization es
# tenemos otro algoritmo
# calcular la solucion y el valor

# %% [markdown]
# <h1> Diseñar el algoritmo </h1>
# <p>
#     La clave para obtener un algoritmo eficiente es el arreglo $M$. Una vez que obtuvimos el arreglo $M$.
#     La respuesta de la instancia completa está contenida en $M\left[ n\right]$
# </p>
# <p>
#     Lo importante de esto notar que se pueden calcular las entradas de $M$ con un algoritmo iterativo en lugar de una
#     recursión memoizada.
# </p>

# %%
# %run intro_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="940">

# %% [markdown]
# [Siguiente](http://localhost:8888/notebooks/prog-dinamica/knapsack/ssum_knapsack_nota.ipynb#El-problema)
