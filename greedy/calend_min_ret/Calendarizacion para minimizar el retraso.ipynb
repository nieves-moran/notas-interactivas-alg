# %% [markdown]
# <h1>Calendarización para minimizar el retraso </h1>

# %% [markdown]
# <p>
#     Tenemos el siguiente problema: contamos con un simple recurso y un conjunto de $n$ peticiones que
#     utilizan el recurso por un intervalo de tiempo. Supongamos que tal recurso comienza a estar disponible en
#     el tiempo $s$. Ahora, en lugar de tener un tiempo de inicio y de finalización como en el problema
#     anterior, el intervalo $i$  tiene un tiempo límite $d_i$ y requiere un intervalo de tiempo $t_i$ para finalizarse.
#     Los intervalos, por supuesto, tienen que asignarse en intervalos que no se traslapen.
# </p>
# <p>
#     Podemos calendarizar todas las peticiones pero podemos dejar que ciertas peticiones se ejecuten tarde.
#     Entonces al principio, en el tiempo $s$, asignamos un intervalo $i$ cuyo intervalo de tiempo es $t_i$. Denotemos
#     este intervalo como $[s(i),f(i)]$, donde $f(i) = s(i) + t_i$. Notemos que este algoritmo tiene que determinar el
#     tiempo de inicio de los intervalos en la calendarización.
# </p>
#
# <p>
#     Ahora, hablemos de lo que queremos optimizar. Decimos que una petición $i$ está retrasada si se calendarizó después
#     de su tiempo límite, esto es si $s(i) > d_i$. El retraso de tal petición lo definimos como $l_i = f(i) - d_i$.
#     Si la petición no está retrasada $l_i = 0$. Nuestro objetivo será calendarizar todas la peticiones, usando intervalos
#     no traslapados, para minimizar el máximo retraso. $L = \max_i l_i $.
# </p>
# Imagen de ejemplo

# %% [markdown]
# <h1> Diseño del Algoritmo</h1>

# %% [markdown]
# <p>
#     Como en el problema anterior, hay algunas reglas voraces que podemos proponer. Veamos algunas que no funcionan
#     junto con las situaciones para las cuales tal regla falla.
# </p>

# %% [markdown]
# <p>
# La regla que funciona es la siguiente: ordenamos las peticiones en orden creciente de acuerdo a su tiempo limite y
#     las calendarizamos. La intuición que inspira a esta regla es simplemente que los trabajos con un tiempo límite más
#     pequeño , tienen que ser tomados en cuenta antes. Esta regla voraz es curiosa ya que la información sobre la
#     longitud del intervalo de tiempo de las peticiones es completamente ignorada. Sin embargo, demostraremos que
#     calcula correctamente el mínimo.
#   </p>
#  <p>
# Primero un poco de notacion
# los trabajo se llaman con respecto a su deadline
# los ponemos en orden
# el tiempo 1 va a comenzar en s el tiempo 2 va a comenar en f1 y entonces el algoritmo es el siguinet
# </p>

# %% [markdown]
# <h1> Analizando el algoritmo </h1>
# vamos a considerar a O un optimal schedule. nuestor plan es mofdific ar O preservando la optimalidad en cada paso.
# pero eventualmente transpormandolo en una calend A que el algoritmo greedy encuentra. Este tipo de analizais se
# denomina agumenteo por intervambi ye es una forma pordersoa para demostras este tiepode algorimtos
#
# Ahora vasmos a hablar de inversion es decimos que una calendarizacion tiene una intversoin sdi u ntravajo i con un d_i
# y un  trabajo j con un deadline y ademoaes  el deadlin d_j < d_i y esta calendarizado primero i. Primeero, o sea, antes
# que j.
# Tenemso que mosrar algo y vamos a mostrar que todos los schedules si inversion y si nteimpo idle tiemne el mismo
# maximum latenes s
#
# Ahora se muestra rque hay una calendarizacoin optima que no tiene inversiones y no tienen tiempo muerto, o sea, hay una, ]
# sabemos que hay una

# %%
un widget que calendarice en aleatorio, encuentre una inversion la desinvierta y se vea como disminuye el maximum lateness

# %%
# %run calend_min_ret.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="1839">

# %% [markdown]
# <h1> Analizando el algoritmo</h1>
