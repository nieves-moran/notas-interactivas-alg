# %%
# %run agpm_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="984">
# ...
# son 16 pos_nodos
# grupos tiene 15
# las coordenadas son (15, 14)
# las coordenadas son (15, 12)
# las coordenadas son (15, 10)
# las coordenadas son (15, 8)
# las coordenadas son (15, 6)
# las coordenadas son (15, 4)
# las coordenadas son (15, 2)
# las coordenadas son (15, 0)
# las coordenadas son (15, -2)
# las coordenadas son (15, -4)
# las coordenadas son (15, -6)
# las coordenadas son (15, -8)
# las coordenadas son (15, -10)
# las coordenadas son (15, -12)
# las coordenadas son (15, -14)
# son 16 pos_nodos
# grupos tiene 14
# las coordenadas son (15, 14)
# las coordenadas son (15, 12)
# las coordenadas son (15, 10)
# las coordenadas son (15, 8)
# las coordenadas son (15, 6)
# las coordenadas son (15, 4)
# las coordenadas son (15, 2)
# las coordenadas son (15, 0)
# las coordenadas son (15, -2)
# las coordenadas son (15, -4)
# las coordenadas son (15, -6)
# las coordenadas son (15, -8)
# las coordenadas son (15, -10)
# ...
