# %% [markdown]
# El problema
# Queremos una red, cada nodo tiene un camino a otra
# tenemos una grafica G(V,E) donde cada arista tiene un costo asociado
# El problmea es encontrar un subconjunto de E, tal que la siguiente suma es el minimo,
# si no es conexa entonces no hay solucion
#
# Proposicion, este debe ser un arbol
# demostrando que no puede haber un ciclo
# si permitimos que haya algunos con 0, puede tener aristas extra pero siempre podemos sacar un arbol de
# este conjunto de vertices
# Una grafica puede tener muchos arboles generadores minimos.
#
# hay 3 algoritmos
#     los algoritmos son los siguientes add
#        uno de los algoritmo agrega aristas en orden mientras no se cree un ciclo,
#        este es el algorimto de kruskal
#
#        otro algorimto se parece a dijkstra, empezamos con un vertice y agregamos
#        añadimos un nodo que minimice el attachment cost
#        tiene que minimizar los siguiente min e en las aristas donde u esta en s y Ce
#
#        Finalmente una version similar a Kruskal pero al reves
#        o sea, eliminar en orden decreciente mientras no desconecten la grafica
#
#
# Tenemos un conjunto de nodos S que no es igual a todos los nodos de la grafica. Y tenemos un arista
# que tiene un extremo en S y otro extremo en V - S, entonces e pertenece al arbol.
#
# El argumento es por exchange argument, lo que haces es tomar un arbol que ya tienes e intercambiar una
# arista, las arista pues es la mejor, o sea la minima. Solo hay que ver que sigue siendo un arbol, es decir
# es conexa y no tiene ciclos
#
# imagen
#
# optimalidad de kruskal
# optimalidad de prim
#
# implementacion de prim
# Dijkstra and prim, almost identical
# With the attachment cost, in a heap,
#
#
# implementacion de kruskal
# union find data structure
# de que trata

# %%
# %run agpm_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_3152\1162359973.py:324, in <module>
#     322 env.vars['cid_t2'] = None
#     323 crear_aleatoria('g1')
# --> 324 env.vars['g2'] = clonar_grafica(env.vars['g1'])
#     325 env.vars['e1'] = Ejecucion('g1','ax1','fig1','cid_t2')
#     326 env.vars['e2'] = Ejecucion('g2','ax2','fig2','cid_t2')
#
# File ~\AppData\Local\Temp\ipykernel_3152\1162359973.py:230, in clonar_grafica(g)
#     228             gc.ady[u][v] = Nodo()
#     229             gc.ady[u][v].peso = g.ady[u][v].peso
# --> 230             gc.ady[v][u] = gc.ady[u][v]
#     231 return gc
#
# KeyError: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [30], in <module>
# ----> 1 get_ipython().run_line_magic('run', 'agpm_alg.ipynb')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:2204, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2202     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2203 with self.builtin_trap:
# -> 2204     result = fn(*args, **kwargs)
#    2205 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\magics\execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:2705, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2703 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2704 if raise_exceptions:
# -> 2705     result.raise_error()
#    2706 elif not result.success:
#    2707     break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:224, in ExecutionResult.raise_error(self)
#     222     raise self.error_before_exec
#     223 if self.error_in_exec is not None:
# --> 224     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_3152\1162359973.py:324, in <module>
#     322 env.vars['cid_t2'] = None
#     323 crear_aleatoria('g1')
# --> 324 env.vars['g2'] = clonar_grafica(env.vars['g1'])
#     325 env.vars['e1'] = Ejecucion('g1','ax1','fig1','cid_t2')
#     326 env.vars['e2'] = Ejecucion('g2','ax2','fig2','cid_t2')
#
# File ~\AppData\Local\Temp\ipykernel_3152\1162359973.py:230, in clonar_grafica(g)
#     228             gc.ady[u][v] = Nodo()
#     229             gc.ady[u][v].peso = g.ady[u][v].peso
# --> 230             gc.ady[v][u] = gc.ady[u][v]
#     231 return gc
#
# KeyError: 0

# %%
# %run prim_alg.ipynb
# Out:
# Output()
# <img src="data:image/png;base64,..." width="640">
