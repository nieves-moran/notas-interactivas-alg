# %%
import ipywidgets as widgets 
from IPython.display import display 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib nbagg

# %% [markdown]
# ## Animación con Sliders

# %%
x = np.linspace(0,2,1000)
#10*4
fig,ax = plt.subplots(1,figsize=(10,4))
plt.suptitle('Sine Wave')

def update_plot(amp,phase,freq): 
    """
    This function is linked to the sliders and it 
    replots the sine wave when the sliders are changed
    """
    ax.clear()
    y = amp*np.sin(2*np.pi*(freq*x + phase))
    ax.plot(x,y)
    plt.show()
    
amp = widgets.FloatSlider(min = 1,max = 10,val =1, description = 'Amp:')
phase = widgets.FloatSlider(min = 0,max = 5,val =0, description = 'Phase:')
freq = widgets.FloatSlider(min = 1,max = 10,val =1, description = 'Freq:')

widgets.interactive(update_plot,amp = amp,phase=phase,freq=freq)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# interactive(children=(FloatSlider(value=1.0, description='Amp:', max=10.0, min=1.0), FloatSlider(value=0.0, de…

# %% [markdown]
# ## Animación con botones

# %%
x = np.linspace(0,2,1000)
#10*4
fig,ax = plt.subplots(1,figsize=(10,4))
plt.suptitle('Sine Wave')

curr_amp = 1 
curr_phase = 1
curr_freq = 0 

def update_amp(b): 
    global curr_amp,x; 
    ax.clear()
    y = curr_amp*np.sin(2*np.pi*(curr_freq*x + curr_phase))
    curr_amp = curr_amp + 1; 
    ax.plot(x,y)
    plt.show()

def update_phase(b): 
    global curr_phase; 
    ax.clear()
    y = curr_amp*np.sin(2*np.pi*(curr_freq*x + curr_phase))
    curr_phase = curr_phase + 1
    ax.plot(x,y)
    plt.show()
def update_freq(b): 
    global curr_freq; 
    ax.clear()
    y = curr_amp*np.sin(2*np.pi*(curr_freq*x + curr_phase))
    curr_freq = curr_freq + 1 
    ax.plot(x,y)
    plt.show()

amp = widgets.Button(description = 'aumenta la amplitud') 
phase = widgets.Button(description = 'aumenta la fase') 
freq = widgets.Button(description = 'aumenta frecuencia') 

amp.on_click(update_amp)
phase.on_click(update_phase)
freq.on_click(update_freq)
display(amp,phase,freq)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Button(description='aumenta la amplitud', style=ButtonStyle())
# Button(description='aumenta la fase', style=ButtonStyle())
# Button(description='aumenta frecuencia', style=ButtonStyle())

# %% [markdown]
# ## Cambiar color de cuadrados

# %%
def cell2():
    import matplotlib.pyplot as plt
    from matplotlib.patches import Rectangle
    from IPython.display import display, Markdown, clear_output

    #define Matplotlib figure and axis
    fig, ax = plt.subplots()


    #create simple line plot
    #ax.plot()
    plt.xticks(range(1,30))
    plt.yticks(range(1,15))
    #display plot
    plt.gca().set_aspect('equal', adjustable='box')


    rangos = [(1,11),(4,12),(6,9),(19,23)]

    #add rectangle to plot
    i = 1
    rangs = []
    for (x,y) in rangos:
        r = Rectangle((x, i), y-x, 1)
        rangs.append(r)
        ax.add_patch(r)
        i = i + 2

    plt.show()
    j = 0 
    button = widgets.Button(description='My Button')
    out = widgets.Output()
    def on_button_clicked(_):
        color_i = np.random.randint(3); 
        colors = ['red','yellow','black']
        rect_i = np.random.randint(len(rangs))
        rangs[rect_i].set(color = colors[color_i]); 
        ax.add_patch(r)
          # "linking function with output" 
    # linking button and function together using a button's method
    button.on_click(on_button_clicked)
    # displaying button and its output together
    box = widgets.VBox([button,out])
    display(box)

cell2()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
class cell_2:
    def __init__(self):
        self.rangos = [(1,11),(4,12),(6,9),(19,23)]
        self.rangs = []
        self.j = 0
    def main(self):
        import matplotlib.pyplot as plt
        from matplotlib.patches import Rectangle
        from IPython.display import display, Markdown, clear_output
        fig, ax = plt.subplots()


        #create simple line plot
        #ax.plot()
        plt.xticks(range(1,30))
        plt.yticks(range(1,15))
        #display plot
        plt.gca().set_aspect('equal', adjustable='box')
        
        #add rectangle to plot
        i = 1
        for (x,y) in self.rangos:
            r = Rectangle((x, i), y-x, 1)
            self.rangs.append(r)
            ax.add_patch(r)
            i = i + 2

        plt.show()
        self.button_config()
        
    def button_config(self): 
        button = widgets.Button(description='My Button')
        out = widgets.Output()
        button.on_click(self.on_button_clicked)
        # displaying button and its output together
        box = widgets.VBox([button,out])
        display(box)
    def on_button_clicked(self,_):
        if(self.j == len(self.rangs)): 
            return
        self.rangs[self.j].set(color = 'red'); 
        self.j = self.j + 1

        
c = cell_2() 
c.main()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
class cell_3:
    def __init__(self):
        self.rangos = [(1,11),(4,12),(6,9),(19,23)]
        self.rangs = []
        self.j = 0
        self.ax = None
        self.prev_line = None
    def main(self):
        import matplotlib.pyplot as plt
        from matplotlib.patches import Rectangle
        from IPython.display import display, Markdown, clear_output
        fig, self.ax = plt.subplots()


        #create simple line plot
        #ax.plot()
        plt.xticks(range(1,30))
        plt.yticks(range(1,15))
        #display plot
        plt.gca().set_aspect('equal', adjustable='box')
        
        #add rectangle to plot
        i = 1
        for (x,y) in self.rangos:
            r = Rectangle((x, i), y-x, 1)
            self.rangs.append(r)
            self.ax.add_patch(r)
            i = i + 2

        plt.show()
        self.button_config()
        
    def button_config(self): 
        button = widgets.Button(description='Siguiente')
        out = widgets.Output()
        button.on_click(self.on_button_clicked)
        # displaying button and its output together
        box = widgets.VBox([button,out])
        display(box)
    def on_button_clicked(self,_):
        if(self.j == len(self.rangs)): 
            return
        r = self.rangs[self.j]
        if(self.prev_line != None): 
            self.prev_line.set(visible = False)
        line = self.ax.axvline(r.get_x() + r.get_width())
        self.prev_line = line; 
        r.set(color = 'red'); 
        self.j = self.j + 1

        
c = cell_3() 
c.main()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
import ipywidgets as widgets 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Rectangle
from IPython.display import display, Markdown, clear_output
# %matplotlib nbagg 
class cell_4:
    def __init__(self,rangos):
        #sacar el maximo 
        maxim_y = float('-inf')
        for (x,y) in rangos:
            maxim_y = max(maxim_y,y)
        ##ordenalos 
        def takeSecond(elem):
            return elem[1]
        rangos.sort(key=takeSecond)
        self.maxim_y = maxim_y
        self.rangos = rangos
        self.rangs = []
        self.j = 0
        self.ax = None
        self.prev_line = None
    def main(self):
        fig, self.ax = plt.subplots()


        #create simple line plot
        plt.xticks(range(1,self.maxim_y+5))
        plt.yticks(range(1,len(self.rangos)*2 + 2))
        #display plot
        plt.gca().set_aspect('equal', adjustable='box')
        
        #add rectangle to plot
        i = 1
        for (x,y) in self.rangos:
            r = Rectangle((x, i), y-x, 1)
            self.rangs.append(r)
            self.ax.add_patch(r)
            i = i + 2

        plt.show()
        self.button_config()
        
    def button_config(self): 
        button = widgets.Button(description='Siguiente')
        out = widgets.Output()
        button.on_click(self.on_button_clicked)
        # displaying button and its output together
        box = widgets.VBox([button,out])
        display(box)
    def on_button_clicked(self,_):
        if(self.j == len(self.rangs)): 
            return
        r = self.rangs[self.j]
        #si el intervalo esta entre la linea pintalo de rojo 
        if(self.prev_line != None and 
           r.get_x() <= self.prev_line.get_xdata()[0]  and 
           self.prev_line.get_xdata()[0] <= r.get_x() + r.get_width()): 
            r.set(color = 'red')
        else:
            #quita la linea 
            if(self.prev_line != None): 
                self.prev_line.set(visible = False)
            #pon la nueva linea 
            line = self.ax.axvline(r.get_x() + r.get_width())
            self.prev_line = line; 

            r.set(color = 'green'); 
        self.j = self.j + 1
        
c = cell_4([(1,11),(4,12),(6,9),(10,15),(13,16),(11,23),(16,19),(22,25)]) 
c.main()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ...
